# %% [markdown]
# # **1. Interesting Topic Selection with 9+ categories**

# %% [markdown]
# **Topic: Traditional Clothing Recognition**
#
# -	1	.	   "kimono (Japan)",
# -	2	.	    "hanbok (South Korea)",
# -	3	.	    "cheongsam/qipao (China)",
# -	4	.	    "sari (India)",
# -	5	.	    "thawb/dishdasha (Saudi Arabia)",
# -	6	.	    "dirndl (Germany)",
# -	7	.	    "kilt (Scotland)",
# -	8	.	    "ao dai (Vietnam)",
# -	9	.	    "boubou (West Africa)",
# -	10	.	    "huipil (Mexico)",
# -	11	.	    "sarong (Indonesia)",
# -	12	.	    "chador (Iran)",
# -	13	.	    "traje de flamenca (Spain)",
# -	14	.	    "batik (Malaysia)",
# -	15	.	    "thobe (Palestine)",
# -	16	.	    "national dress (Norway)",
# -	17	.	    "national costume (Philippines)",
# -	18	.	    "barong tagalog (Philippines)",
# -	19	.	    "abaya (United Arab Emirates)",
# -	20	.	    "folkdräkt (Sweden)",
# -	21	.	    "ao po'i (Paraguay)",
# -	22	.	    "pounamu piupiu (New Zealand)",
# -	23	.	    "kaftan (Morocco)"

# %% [markdown]
# Setting Up Neccessary things

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
version = 0
img_path = "test_images"
model_path = f"models/tradiotional_clothing_recognition-v{version}.pth"

# %%
# !pip install -Uqq fastai fastbook nbdev
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 48.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 36.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.5 MB/s eta 0:00:00

# %%
from fastai import *
from fastbook import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Master_Course_Data Science/LastAssignment
# Out:
# /content/drive/MyDrive/Master_Course_Data Science/LastAssignment

# %%
model = load_learner(model_path)

# %% [markdown]
# ## **Interface - 1**

# %% [markdown]
# **Target: Kimono**

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-1.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-1.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('kimono _Japan_',
#  tensor(15),
#  tensor([9.5161e-06, 3.6229e-06, 9.8130e-07, 1.6634e-07, 1.6813e-06, 1.4333e-06, 8.9108e-06, 2.8276e-05, 1.5598e-07, 7.3271e-06, 4.8920e-06, 1.6988e-06, 8.1267e-07, 2.4682e-06, 3.7516e-01, 6.2474e-01,
#          3.4189e-06, 9.3020e-08, 5.9605e-07, 1.0238e-06, 7.2168e-06, 9.2012e-06, 7.8199e-06]))

# %% [markdown]
# ## **Interface - 2**

# %% [markdown]
# **Target: Sari India**

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-2.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x83>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-2.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('sari _India_',
#  tensor(18),
#  tensor([8.8420e-06, 5.4527e-05, 8.3269e-06, 4.0551e-07, 1.3046e-03, 4.3033e-03, 6.0482e-05, 5.4049e-06, 3.6385e-06, 3.4103e-07, 1.3757e-06, 5.9362e-05, 7.8182e-05, 1.2246e-07, 3.4095e-07, 2.7926e-07,
#          9.9912e-04, 3.8015e-06, 9.9283e-01, 2.7002e-04, 3.0319e-06, 9.9097e-07, 1.2860e-06]))
