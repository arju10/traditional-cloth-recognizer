# %% [markdown]
# # **1. Interesting Topic Selection with 9+ categories**

# %% [markdown]
# **Topic: Traditional Clothing Recognition**
#
# 1. KIMONO (JAPAN)
# 2. HANBOK (SOUTH KOREA)
# 3. CHEONGSAM/QIPAO (CHINA)
# 4. SARI (INDIA)
# 5. THAWB/DISHDASHA (SAUDI ARABIA)
# 6. DIRNDL (GERMANY)
# 7. KILT (SCOTLAND)
# 8. AO DAI (VIETNAM)
# 9. BOUBOU (WEST AFRICA)
# 10. HUIPIL (MEXICO)
# 11. SARONG (INDONESIA)
# 12. CHADOR (IRAN)
# 13. TRAJE DE FLAMENCA (SPAIN)
# 14. BATIK (MALAYSIA)
# 15. THOBE (PALESTINE)
# 16. NATIONAL DRESS (NORWAY)
# 17. NATIONAL COSTUME (PHILIPPINES)
# 18. BARONG TAGALOG (PHILIPPINES)
# 19. ABAYA (UNITED ARAB EMIRATES)
# 20. FOLKDRÄKT (SWEDEN)
# 21. AO PO'I (PARAGUAY)
# 22. POUNAMU PIUPIU (NEW ZEALAND)
# 23. KAFTAN (MOROCCO)

# %% [markdown]
# Setting Up Neccessary things

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
version = 2
img_path = "test_images"
model_path = f"models/tradiotional_clothing_recognition-v{version}.pth"

# %%
# !pip install -Uqq fastai fastbook nbdev
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 23.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 39.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.6 MB/s eta 0:00:00
# ...

# %%
from fastai import *
from fastbook import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Master_Course_Data Science/LastAssignment
# Out:
# /content/drive/MyDrive/Master_Course_Data Science/LastAssignment

# %%
from fastai.learner import load_learner

# %%
model_path = "models/tradiotional_clothing_recognition-v2.pkl"
# model_path = f"models/tradiotional_clothing_recognition-v{version}.pth"
model = load_learner(model_path)

# %% [markdown]
# ## **Interface - 1**

# %% [markdown]
# **Target: Kimono**

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-1.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-1.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('KIMONO _JAPAN_',
#  tensor(12),
#  tensor([3.2045e-08, 6.0282e-07, 4.9409e-09, 7.4864e-08, 9.5293e-07, 5.1336e-09, 1.5247e-08, 3.3995e-10, 5.3091e-08, 3.9069e-08, 2.0197e-08, 1.3735e-07, 9.9999e-01, 5.1628e-06, 4.1144e-09, 7.4510e-10,
#          4.5912e-09, 1.3845e-06, 2.6237e-09]))

# %% [markdown]
# ## **Interface - 2**

# %% [markdown]
# **Target: Sari India**

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-5.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-5.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('SARI _INDIA_',
#  tensor(16),
#  tensor([2.1615e-03, 4.0613e-03, 5.2321e-06, 2.2380e-05, 4.8255e-03, 4.0503e-05, 6.9150e-05, 1.2102e-05, 3.1727e-03, 3.3897e-05, 5.3296e-02, 2.0422e-04, 1.1439e-04, 3.3363e-01, 3.5244e-05, 5.0961e-04,
#          5.9719e-01, 5.2682e-04, 8.8665e-05]))

# %% [markdown]
# **Target: KAFTAN (MOROCCO)**

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-3.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-3.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('KAFTAN _MOROCCO_',
#  tensor(10),
#  tensor([1.9725e-02, 2.0820e-03, 1.2629e-06, 1.2127e-04, 5.3724e-05, 2.8677e-05, 1.7111e-05, 6.8487e-04, 6.7013e-05, 1.5460e-05, 9.7240e-01, 1.8043e-04, 2.1026e-03, 8.2705e-04, 3.3219e-04, 9.8326e-05,
#          1.2514e-03, 2.1643e-06, 1.1679e-05]))

# %% [markdown]
# ### BOUBOU (WEST AFRICA)

# %%
img = Image.open("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-6.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
model.predict("/content/drive/MyDrive/Master_Course_Data Science/LastAssignment/test_images/unknown-6.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('BOUBOU _WEST AFRICA_',
#  tensor(5),
#  tensor([2.2004e-03, 6.2175e-04, 5.0356e-02, 6.9889e-02, 1.7995e-04, 7.2953e-01, 1.7118e-02, 4.9179e-03, 7.5157e-03, 6.9912e-02, 8.1447e-03, 1.2567e-04, 8.6704e-03, 7.6275e-03, 1.0879e-03, 3.8915e-03,
#          6.9042e-03, 1.4779e-03, 9.8335e-03]))
