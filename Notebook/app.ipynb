# %%
# !pip install -Uqq fastai gradio nbdev
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 27.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.2/294.2 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from fastai.vision.all import *

# %%
#!export
from fastai.vision.all import load_learner
import gradio as gr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Master_Course_Data Science/LastAssignment
# Out:
# /content/drive/MyDrive/Master_Course_Data Science/LastAssignment

# %%
#!export
model = load_learner('models/tradiotional_clothing_recognition-v1.pkl')

# %%
categories = [
   "KIMONO (JAPAN)",
    "HANBOK (SOUTH KOREA)",
    "CHEONGSAM/QIPAO (CHINA)",
    "SARI (INDIA)",
    "THAWB/DISHDASHA (SAUDI ARABIA)",
    "DIRNDL (GERMANY)",
    "KILT (SCOTLAND)",
    "AO DAI (VIETNAM)",
    "BOUBOU (WEST AFRICA)",
    "HUIPIL (MEXICO)",
    "SARONG (INDONESIA)",
    "CHADOR (IRAN)",
    "TRAJE DE FLAMENCA (SPAIN)",
    "BATIK (MALAYSIA)",
    "THOBE (PALESTINE)",
    "NATIONAL DRESS (NORWAY)",
    "NATIONAL COSTUME (PHILIPPINES)",
    "BARONG TAGALOG (PHILIPPINES)",
    "ABAYA (UNITED ARAB EMIRATES)",
    "FOLKDRÄKT (SWEDEN)",
    "AO PO'I (PARAGUAY)",
    "POUNAMU PIUPIU (NEW ZEALAND)",
    "KAFTAN (MOROCCO)"
]
# def recognize_image(image):
#   pred, idx, probs = model.predict(image)
#   return dict(zip(sorted(categories, map(float, probs))))

def recognize_image(image):
    pred, idx, probs = model.predict(image)
    return dict(zip(sorted(categories), map(float, probs)))

# %%
img = PILImage.create(f'test_images/unknown-1.jpg')
img.thumbnail((192,192))
img
# Out:
# PILImage mode=RGB size=192x192

# %%
recognize_image(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'ABAYA (UNITED ARAB EMIRATES)': 5.2136801542701505e-09,
#  'AO DAI (VIETNAM)': 3.8817680092506635e-07,
#  "AO PO'I (PARAGUAY)": 4.2737188787889124e-10,
#  'BARONG TAGALOG (PHILIPPINES)': 7.477908570141523e-11,
#  'BATIK (MALAYSIA)': 2.3851260966267773e-09,
#  'BOUBOU (WEST AFRICA)': 6.892130199886992e-10,
#  'CHADOR (IRAN)': 2.8864597378941426e-09,
# ...

# %%
img = PILImage.create(f'test_images/unknown-6.jpg')
img.thumbnail((192,192))
img
# Out:
# PILImage mode=RGB size=144x192

# %%
recognize_image(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'ABAYA (UNITED ARAB EMIRATES)': 2.0577258510456886e-06,
#  'AO DAI (VIETNAM)': 2.978152906507603e-07,
#  "AO PO'I (PARAGUAY)": 0.00011985862511210144,
#  'BARONG TAGALOG (PHILIPPINES)': 0.00019182419055141509,
#  'BATIK (MALAYSIA)': 2.0184272216283716e-05,
#  'BOUBOU (WEST AFRICA)': 0.9944612979888916,
#  'CHADOR (IRAN)': 5.0027159886667505e-05,
# ...

# %%
#!export
image = gr.inputs.Image(shape=(192,192))
label = gr.outputs.Label()
examples = [
    'test_images/unknown-6.jpg',
    'test_images/unknown-16.jpg',
    'test_images/unknown-18.jpg',
    ]

iface = gr.Interface(fn=recognize_image, inputs=image, outputs=label, examples=examples)
iface.launch(inline=False, share=True)
# Out:
# <ipython-input-33-002e914b88ef>:2: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   image = gr.inputs.Image(shape=(192,192))
# <ipython-input-33-002e914b88ef>:2: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   image = gr.inputs.Image(shape=(192,192))
# <ipython-input-33-002e914b88ef>:3: GradioDeprecationWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   label = gr.outputs.Label()
# <ipython-input-33-002e914b88ef>:3: GradioUnusedKwargWarning: You have unused kwarg parameters in Label, please remove them: {'type': 'auto'}
#   label = gr.outputs.Label()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://2dc61d1241a78b8fcb.gradio.live
#
# ...

# %% [markdown]
# Notebook to Python Script Export

# %%
# !pip install nbdev

# %%
from nbdev.export import notebook2script

# %%
notebook2script('app.ipynb')
